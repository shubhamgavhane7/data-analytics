# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(10,4),
               index=pd.date_range('1/12/2000',periods=10),columns=list('ABCD'))
print(df)
df.plot()
# Out:
#                    A         B         C         D
# 2000-01-12  1.383059 -0.491623 -1.443259 -0.696442
# 2000-01-13  1.177791 -1.598616  1.406991  0.765689
# 2000-01-14  1.968907 -0.097334  0.233804 -0.812715
# 2000-01-15 -0.117064 -1.412802  0.392491  0.178170
# 2000-01-16  0.038179  0.352255 -0.908364  0.181150
# 2000-01-17 -1.293972  0.169076 -0.619548 -0.298832
# 2000-01-18 -1.062948 -0.690542 -0.269608 -0.118615
# 2000-01-19  0.246532  1.317106  0.405511 -0.747062
# 2000-01-20 -0.648359 -1.027661 -0.518821  0.119395
# 2000-01-21 -0.355418 -1.642627 -0.375568 -1.368332

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(10,2),
               index=pd.date_range('1/12/2000',periods=10),columns=list(['A','D']))
print(df)
df.plot()
# Out:
#                    A         D
# 2000-01-12 -0.006762  0.430593
# 2000-01-13  0.587892  0.777257
# 2000-01-14 -1.269658  1.342634
# 2000-01-15  0.419760 -0.012058
# 2000-01-16  0.376050 -0.570990
# 2000-01-17 -0.229644 -0.510693
# 2000-01-18 -0.392803 -0.870002
# 2000-01-19  1.312007  0.149026
# 2000-01-20 -1.769676 -1.956533
# 2000-01-21 -0.105719 -1.338990

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(10,4),columns=list('ABCD'))
print(df)
df.plot.bar()
# Out:
#           A         B         C         D
# 0  0.812974  0.728962  0.632829  0.241616
# 1  0.373569  0.482752  0.561641  0.735038
# 2  0.600914  0.188656  0.600054  0.622709
# 3  0.580275  0.077892  0.138408  0.756470
# 4  0.146232  0.840291  0.786215  0.310344
# 5  0.695232  0.447535  0.172912  0.289049
# 6  0.169948  0.702471  0.628541  0.409272
# 7  0.693237  0.746755  0.899397  0.223365
# 8  0.979193  0.175836  0.301410  0.573861
# 9  0.198338  0.283736  0.187564  0.170062

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
print(df)
df.plot.bar(stacked=True)
# Out:
#           a         b         c         d
# 0  0.453567  0.302077  0.818749  0.138661
# 1  0.398389  0.150306  0.159033  0.593518
# 2  0.734754  0.451226  0.888762  0.937578
# 3  0.258370  0.110994  0.332294  0.775175
# 4  0.876452  0.089453  0.009884  0.502351
# 5  0.682118  0.499178  0.640549  0.340282
# 6  0.367957  0.064410  0.228286  0.188600
# 7  0.330121  0.816847  0.647738  0.091942
# 8  0.478606  0.250836  0.658983  0.003018
# 9  0.293226  0.694022  0.293951  0.420048

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
print(df)
df.plot.barh(stacked=True)
# Out:
#           a         b         c         d
# 0  0.601416  0.270611  0.978294  0.492341
# 1  0.246306  0.763709  0.392514  0.548085
# 2  0.439827  0.237405  0.763024  0.028016
# 3  0.396062  0.890946  0.225626  0.998608
# 4  0.354571  0.333208  0.161492  0.567599
# 5  0.685386  0.498207  0.253677  0.230964
# 6  0.593137  0.755489  0.299170  0.790487
# 7  0.772772  0.119812  0.450186  0.826501
# 8  0.300295  0.310701  0.989111  0.042970
# 9  0.539106  0.929474  0.845348  0.477971

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({'a':np.random.randn(1000)+5,'b':np.random.randn(1000)+8,'c':np.random.randn(1000)+7},columns=['a','b','c'])
print(df)
df.plot.hist(bins=20)
# Out:
#             a         b          c
# 0    4.829520  8.969245   6.102582
# 1    4.580361  9.373217   6.802530
# 2    5.554106  8.177880   6.329961
# 3    6.160785  6.772442   4.693881
# 4    4.165327  8.500254   5.188395
# 5    4.560773  9.626451   6.110610
# 6    6.453146  7.739709   8.423074
# 7    6.208887  7.963663   6.612656
# 8    4.023543  8.721645   4.990710
# 9    6.229768  8.480228   6.940675
# 10   4.613707  6.982704   6.586702
# 11   5.173451  6.861122   7.320060
# 12   6.254471  8.093213   4.760734
# 13   6.129489  8.111820  10.386259
# 14   4.647778  7.616082   7.633105
# 15   2.433777  7.748978   6.803992
# 16   4.435111  8.676540   6.821415
# 17   5.510828  8.730394   6.195434
# 18   4.519180  6.674651   8.280823
# 19   5.327381  6.950546   7.687071
# 20   5.353333  7.837664   8.152084
# 21   5.336940  7.998941   5.769963
# 22   6.010829  8.439661   8.619246
# 23   4.784723  8.411869   6.266046
# 24   4.189544  8.721552   5.609417
# 25   4.569607  8.661906   5.564949
# ...

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(10,5),columns=['A','B','C','D','E'])
print(df)
df.plot.area()
# Out:
#           A         B         C         D         E
# 0  0.057277  0.585827  0.817789  0.596879  0.345739
# 1  0.500079  0.574613  0.338358  0.308362  0.972379
# 2  0.755822  0.150865  0.969231  0.790628  0.178745
# 3  0.625083  0.220678  0.348129  0.094243  0.520229
# 4  0.584985  0.643691  0.332346  0.708869  0.649784
# 5  0.393922  0.732036  0.093204  0.794333  0.502540
# 6  0.248630  0.330171  0.319395  0.136061  0.495734
# 7  0.021338  0.104750  0.926142  0.273533  0.222041
# 8  0.664259  0.781577  0.448610  0.269720  0.061861
# 9  0.255601  0.527196  0.228320  0.676004  0.077893

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(50,4),columns=['a','b','c','d'])
print(df)
df.plot.scatter(x='a',y='b')
# Out:
#            a         b         c         d
# 0   0.451607  0.863176  0.846727  0.830834
# 1   0.480772  0.962185  0.690585  0.875619
# 2   0.461395  0.505939  0.239143  0.874330
# 3   0.389518  0.341819  0.613220  0.435678
# 4   0.128120  0.665572  0.442398  0.507436
# 5   0.586776  0.987599  0.835761  0.533775
# 6   0.293011  0.096300  0.384379  0.129365
# 7   0.935650  0.574450  0.494561  0.022090
# 8   0.726287  0.013438  0.658272  0.230117
# 9   0.567960  0.512491  0.253739  0.172969
# 10  0.758700  0.260933  0.438502  0.841502
# 11  0.805040  0.847084  0.162234  0.170305
# 12  0.838595  0.302771  0.301151  0.861766
# 13  0.082501  0.673477  0.194767  0.795308
# 14  0.550689  0.404034  0.948238  0.625123
# 15  0.469775  0.511496  0.362846  0.187406
# 16  0.948436  0.282873  0.709686  0.976399
# 17  0.296166  0.423899  0.732426  0.674184
# 18  0.999113  0.594341  0.510446  0.693360
# 19  0.542962  0.961347  0.574249  0.082431
# 20  0.824343  0.277608  0.455752  0.234403
# ...

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(*3np.random.rand(4),index=['a','b','c','d'],columns=['x'])
print(df)
df.plot.pie(subplots=True)
# Out:
#   File "<ipython-input-64-d39666e37e14>", line 3
#     df=pd.DataFrame(*3np.random.rand(4),index=['a','b','c','d'],columns=['x'])
#                        ^
# SyntaxError: invalid syntax
